# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Challenge-1" data-toc-modified-id="Challenge-1-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Challenge 1</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Import-all-required-libraries" data-toc-modified-id="Import-all-required-libraries-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Import all required libraries</a></span></li><li><span><a href="#Import-data-set" data-toc-modified-id="Import-data-set-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>Import data set</a></span></li><li><span><a href="#Print-first-10-rows-of-pokemon" data-toc-modified-id="Print-first-10-rows-of-pokemon-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>Print first 10 rows of <code>pokemon</code></a></span></li><li><span><a href="#Obtain-the-distinct-values-across-Type-1-and-Type-2" data-toc-modified-id="Obtain-the-distinct-values-across-Type-1-and-Type-2-1.0.4"><span class="toc-item-num">1.0.4&nbsp;&nbsp;</span>Obtain the distinct values across <code>Type 1</code> and <code>Type 2</code></a></span></li><li><span><a href="#Cleanup-Name-that-contain-&quot;Mega&quot;" data-toc-modified-id="Cleanup-Name-that-contain-&quot;Mega&quot;-1.0.5"><span class="toc-item-num">1.0.5&nbsp;&nbsp;</span>Cleanup <code>Name</code> that contain "Mega"</a></span></li><li><span><a href="#Create-a-new-column-called-A/D-Ratio-whose-value-equals-to-Attack-devided-by-Defense" data-toc-modified-id="Create-a-new-column-called-A/D-Ratio-whose-value-equals-to-Attack-devided-by-Defense-1.0.6"><span class="toc-item-num">1.0.6&nbsp;&nbsp;</span>Create a new column called <code>A/D Ratio</code> whose value equals to <code>Attack</code> devided by <code>Defense</code></a></span></li><li><span><a href="#Identify-the-pokemon-with-the-highest-A/D-Ratio" data-toc-modified-id="Identify-the-pokemon-with-the-highest-A/D-Ratio-1.0.7"><span class="toc-item-num">1.0.7&nbsp;&nbsp;</span>Identify the pokemon with the highest <code>A/D Ratio</code></a></span></li><li><span><a href="#Identify-the-pokemon-with-the-lowest-A/D-Ratio" data-toc-modified-id="Identify-the-pokemon-with-the-lowest-A/D-Ratio-1.0.8"><span class="toc-item-num">1.0.8&nbsp;&nbsp;</span>Identify the pokemon with the lowest A/D Ratio</a></span></li><li><span><a href="#Create-a-new-column-called-Combo-Type-whose-value-combines-Type-1-and-Type-2." data-toc-modified-id="Create-a-new-column-called-Combo-Type-whose-value-combines-Type-1-and-Type-2.-1.0.9"><span class="toc-item-num">1.0.9&nbsp;&nbsp;</span>Create a new column called <code>Combo Type</code> whose value combines <code>Type 1</code> and <code>Type 2</code>.</a></span></li><li><span><a href="#Identify-the-pokemons-whose-A/D-Ratio-are-among-the-top-5" data-toc-modified-id="Identify-the-pokemons-whose-A/D-Ratio-are-among-the-top-5-1.0.10"><span class="toc-item-num">1.0.10&nbsp;&nbsp;</span>Identify the pokemons whose <code>A/D Ratio</code> are among the top 5</a></span></li><li><span><a href="#For-the-5-pokemons-printed-above,-aggregate-Combo-Type-and-use-a-list-to-store-the-unique-values." data-toc-modified-id="For-the-5-pokemons-printed-above,-aggregate-Combo-Type-and-use-a-list-to-store-the-unique-values.-1.0.11"><span class="toc-item-num">1.0.11&nbsp;&nbsp;</span>For the 5 pokemons printed above, aggregate <code>Combo Type</code> and use a list to store the unique values.</a></span></li><li><span><a href="#For-each-of-the-Combo-Type-values-obtained-from-the-previous-question,-calculate-the-mean-scores-of-all-numeric-fields-across-all-pokemons." data-toc-modified-id="For-each-of-the-Combo-Type-values-obtained-from-the-previous-question,-calculate-the-mean-scores-of-all-numeric-fields-across-all-pokemons.-1.0.12"><span class="toc-item-num">1.0.12&nbsp;&nbsp;</span>For each of the <code>Combo Type</code> values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemons.</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **pokemons**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# ### Import all required libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### Import data set
#
# Import data set `Pokemon.csv` from the `your-code` directory of this lab. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set
pokemon=pd.read_csv("Pokemon.csv")

# %% [markdown]
# ### Print first 10 rows of `pokemon`

# %%
# enter your code here
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# ### Obtain the distinct values across `Type 1` and `Type 2`
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
type1_2=pokemon.loc[:,["Type 1","Type 2"]]

# %%
types=[]
for i in range(len(type1_2)):
    types.append(list(type1_2.iloc[i]))
print(types)
# Out:
# [['Grass', 'Poison'], ['Grass', 'Poison'], ['Grass', 'Poison'], ['Grass', 'Poison'], ['Fire', nan], ['Fire', nan], ['Fire', 'Flying'], ['Fire', 'Dragon'], ['Fire', 'Flying'], ['Water', nan], ['Water', nan], ['Water', nan], ['Water', nan], ['Bug', nan], ['Bug', nan], ['Bug', 'Flying'], ['Bug', 'Poison'], ['Bug', 'Poison'], ['Bug', 'Poison'], ['Bug', 'Poison'], ['Normal', 'Flying'], ['Normal', 'Flying'], ['Normal', 'Flying'], ['Normal', 'Flying'], ['Normal', nan], ['Normal', nan], ['Normal', 'Flying'], ['Normal', 'Flying'], ['Poison', nan], ['Poison', nan], ['Electric', nan], ['Electric', nan], ['Ground', nan], ['Ground', nan], ['Poison', nan], ['Poison', nan], ['Poison', 'Ground'], ['Poison', nan], ['Poison', nan], ['Poison', 'Ground'], ['Fairy', nan], ['Fairy', nan], ['Fire', nan], ['Fire', nan], ['Normal', 'Fairy'], ['Normal', 'Fairy'], ['Poison', 'Flying'], ['Poison', 'Flying'], ['Grass', 'Poison'], ['Grass', 'Poison'], ['Grass', 'Poison'], ['Bug', 'Grass'], ['Bug', 'Grass'], ['Bug', 'Poison'], ['Bug', 'Poison'], ['Ground', nan], ['Ground', nan], ['Normal', nan], ['Normal', nan], ['Water', nan], ['Water', nan], ['Fighting', nan], ['Fighting', nan], ['Fire', nan], ['Fire', nan], ['Water', nan], ['Water', nan], ['Water', 'Fighting'], ['Psychic', nan], ['Psychic', nan], ['Psychic', nan], ['Psychic', nan], ['Fighting', nan], ['Fighting', nan], ['Fighting', nan], ['Grass', 'Poison'], ['Grass', 'Poison'], ['Grass', 'Poison'], ['Water', 'Poison'], ['Water', 'Poison'], ['Rock', 'Ground'], ['Rock', 'Ground'], ['Rock', 'Ground'], ['Fire', nan], ['Fire', nan], ['Water', 'Psychic'], ['Water', 'Psychic'], ['Water', 'Psychic'], ['Electric', 'Steel'], ['Electric', 'Steel'], ['Normal', 'Flying'], ['Normal', 'Flying'], ['Normal', 'Flying'], ['Water', nan], ['Water', 'Ice'], ['Poison', nan], ['Poison', nan], ['Water', nan], ['Water', 'Ice'], ['Ghost', 'Poison'], ['Ghost', 'Poison'], ['Ghost', 'Poison'], ['Ghost', 'Poison'], ['Rock', 'Ground'], ['Psychic', nan], ['Psychic', nan], ['Water', nan], ['Water', nan], ['Electric', nan], ['Electric', nan], ['Grass', 'Psychic'], ['Grass', 'Psychic'], ['Ground', nan], ['Ground', nan], ['Fighting', nan], ['Fighting', nan], ['Normal', nan], ['Poison', nan], ['Poison', nan], ['Ground', 'Rock'], ['Ground', 'Rock'], ['Normal', nan], ['Grass', nan], ['Normal', nan], ['Normal', nan], ['Water', nan], ['Water', nan], ['Water', nan], ['Water', nan], ['Water', nan], ['Water', 'Psychic'], ['Psychic', 'Fairy'], ['Bug', 'Flying'], ['Ice', 'Psychic'], ['Electric', nan], ['Fire', nan], ['Bug', nan], ['Bug', 'Flying'], ['Normal', nan], ['Water', nan], ['Water', 'Flying'], ['Water', 'Dark'], ['Water', 'Ice'], ['Normal', nan], ['Normal', nan], ['Water', nan], ['Electric', nan], ['Fire', nan], ['Normal', nan], ['Rock', 'Water'], ['Rock', 'Water'], ['Rock', 'Water'], ['Rock', 'Water'], ['Rock', 'Flying'], ['Rock', 'Flying'], ['Normal', nan], ['Ice', 'Flying'], ['Electric', 'Flying'], ['Fire', 'Flying'], ['Dragon', nan], ['Dragon', nan], ['Dragon', 'Flying'], ['Psychic', nan], ['Psychic', 'Fighting'], ['Psychic', nan], ['Psychic', nan], ['Grass', nan], ['Grass', nan], ['Grass', nan], ['Fire', nan], ['Fire', nan], ['Fire', nan], ['Water', nan], ['Water', nan], ['Water', nan], ['Normal', nan], ['Normal', nan], ['Normal', 'Flying'], ['Normal', 'Flying'], ['Bug', 'Flying'], ['Bug', 'Flying'], ['Bug', 'Poison'], ['Bug', 'Poison'], ['Poison', 'Flying'], ['Water', 'Electric'], ['Water', 'Electric'], ['Electric', nan], ['Fairy', nan], ['Normal', 'Fairy'], ['Fairy', nan], ['Fairy', 'Flying'], ['Psychic', 'Flying'], ['Psychic', 'Flying'], ['Electric', nan], ['Electric', nan], ['Electric', nan], ['Electric', 'Dragon'], ['Grass', nan], ['Water', 'Fairy'], ['Water', 'Fairy'], ['Rock', nan], ['Water', nan], ['Grass', 'Flying'], ['Grass', 'Flying'], ['Grass', 'Flying'], ['Normal', nan], ['Grass', nan], ['Grass', nan], ['Bug', 'Flying'], ['Water', 'Ground'], ['Water', 'Ground'], ['Psychic', nan], ['Dark', nan], ['Dark', 'Flying'], ['Water', ...

# %% [markdown]
# ### Cleanup `Name` that contain "Mega"
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
#Creo un bucle para encontrar cualese tienen .mega, hago otro bucle para eliminar el principio de cada uno
for i in pokemon.Name:
    if re.findall(".Mega",i):
        for n in range(len(i)):
            if i[n]=="M":
                p=(i[n:])
                pokemon.replace(i,p,inplace=True)
pokemon.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %% [markdown]
# ### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# enter your code here
pokemon["A/D Ratio"]=pokemon["Attack"]/pokemon["Defense"]

# %%
pokemon.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire     NaN    309  39      52       43       60
# 5  5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0       65     45           1      False   1.000000
# 1       80     60           1      False   0.984127
# 2      100     80           1      False   0.987952
# 3      120     80           1      False   0.813008
# 4       50     65           1      False   1.209302
# 5       65     80           1      False   1.103448
# 6       85    100           1      False   1.076923
# 7       85    100           1      False   1.171171
# 8      115    100           1      False   1.333333
# 9       64     43           1      False   0.738462

# %% [markdown]
# ### Identify the pokemon with the highest `A/D Ratio`

# %%
# enter your code here
pokemon.nlargest(1,"A/D Ratio")["Name"]
# Out:
# 429    DeoxysAttack Forme
# Name: Name, dtype: object

# %% [markdown]
# ### Identify the pokemon with the lowest A/D Ratio

# %%
# enter your code here
pokemon.nsmallest(1,"A/D Ratio")["Name"]
# Out:
# 230    Shuckle
# Name: Name, dtype: object

# %% [markdown]
# ### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
#compruebo los nan que tiene el tipo 2
pokemon.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# A/D Ratio       0
# dtype: int64

# %%
#Cambio los valores nulos de tipo 2 por "nothing"
pokemon["Type 2"].fillna("", inplace=True)

# %%
#Creo una lista para almacenar los valores, si el tipo 2 esta vacio solo guardara el primer valor y despues añado la lista a la col
lista=[]
for i in range(len(pokemon["Type 1"])):
    if pokemon["Type 2"][i]=="":
        lista.append(pokemon["Type 1"][i])
    else:
         lista.append(pokemon["Type 1"][i]+"-"+ pokemon["Type 2"][i])
pokemon["Combo Type"]=lista

# %%
pokemon.head(10)
# Out:
#    #              Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2           Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3          Venusaur  Grass  Poison    525  80      82       83      100
# 3  3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4        Charmander   Fire            309  39      52       43       60
# 5  5        Charmeleon   Fire            405  58      64       58       80
# 6  6         Charizard   Fire  Flying    534  78      84       78      109
# 7  6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 8  6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 9  7          Squirtle  Water            314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio    Combo Type
# 0       65     45           1      False   1.000000  Grass-Poison
# 1       80     60           1      False   0.984127  Grass-Poison
# 2      100     80           1      False   0.987952  Grass-Poison
# 3      120     80           1      False   0.813008  Grass-Poison
# 4       50     65           1      False   1.209302          Fire
# 5       65     80           1      False   1.103448          Fire
# 6       85    100           1      False   1.076923   Fire-Flying
# 7       85    100           1      False   1.171171   Fire-Dragon
# 8      115    100           1      False   1.333333   Fire-Flying
# 9       64     43           1      False   0.738462         Water

# %% [markdown]
# ### Identify the pokemons whose `A/D Ratio` are among the top 5

# %%
# enter your code here
pokemon.nlargest(5,"A/D Ratio")
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic            600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock            350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429      180       20    150           3       True      9.000     Psychic
# 347       65       20     65           3      False      4.500  Water-Dark
# 19        15       80    145           1      False      3.750  Bug-Poison
# 453       30       30     58           4      False      3.125        Rock
# 348       95       40     95           3      False      3.000  Water-Dark

# %% [markdown]
# ### For the 5 pokemons printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemons with the highest `A/D Ratio`.

# %%
# enter your code here
combo=set(pokemon.nlargest(5,"A/D Ratio")["Combo Type"])
combo
# Out:
# {'Bug-Poison', 'Psychic', 'Rock', 'Water-Dark'}

# %% [markdown]
# ### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemons.
#
# Your output should look like below:
#
# ![Aggregate](aggregated-mean.png)

# %%
#primera forma que se me ha ocurrido pero no se ve como arriba
for i in combo:
    print(pokemon[pokemon["Combo Type"]==i].mean())
# Out:
# #             199.166667
# Total         347.916667
# HP             53.750000
# Attack         68.333333
# Defense        58.083333
# Sp. Atk        42.500000
# Sp. Def        59.333333
# Speed          65.916667
# Generation      2.333333
# Legendary       0.000000
# A/D Ratio       1.315989
# dtype: float64
# #             347.666667
# Total         493.833333
# HP             69.166667
# Attack        120.000000
# Defense        65.166667
# Sp. Atk        88.833333
# Sp. Def        63.500000
# Speed          87.166667
# Generation      3.166667
# Legendary       0.000000
# A/D Ratio       2.291949
# dtype: float64
# #             410.111111
# Total         409.444444
# HP             67.111111
# Attack        103.333333
# Defense       107.222222
# Sp. Atk        40.555556
# Sp. Def        58.333333
# Speed          32.888889
# Generation      3.888889
# Legendary       0.111111
# A/D Ratio       1.260091
# dtype: float64
# #             381.973684
# Total         464.552632
# HP             72.552632
# Attack         64.947368
# Defense        67.236842
# Sp. Atk        98.552632
# Sp. Def        82.394737
# Speed          78.868421
# Generation      3.342105
# Legendary       0.236842
# A/D Ratio       1.164196
# dtype: float64
